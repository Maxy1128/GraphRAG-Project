# %%
# Copyright (c) 2024 Microsoft Corporation.
# Licensed under the MIT License.

# %%
import os
from pathlib import Path

import pandas as pd
import tiktoken

from graphrag.config.enums import ModelType
from graphrag.config.models.drift_search_config import DRIFTSearchConfig
from graphrag.config.models.language_model_config import LanguageModelConfig
from graphrag.language_model.manager import ModelManager
from graphrag.query.indexer_adapters import (
    read_indexer_entities,
    read_indexer_relationships,
    read_indexer_report_embeddings,
    read_indexer_reports,
    read_indexer_text_units,
)
from graphrag.query.structured_search.drift_search.drift_context import (
    DRIFTSearchContextBuilder,
)
from graphrag.query.structured_search.drift_search.search import DRIFTSearch
from graphrag.vector_stores.lancedb import LanceDBVectorStore

INPUT_DIR = "your_input_directory"
LANCEDB_URI = f"{INPUT_DIR}/lancedb"

COMMUNITY_REPORT_TABLE = "community_reports"
COMMUNITY_TABLE = "communities"
ENTITY_TABLE = "entities"
RELATIONSHIP_TABLE = "relationships"
COVARIATE_TABLE = "covariates"
TEXT_UNIT_TABLE = "text_units"
COMMUNITY_LEVEL = 2


# read nodes table to get community and degree data
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
community_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_TABLE}.parquet")

print(f"Entity df columns: {entity_df.columns}")

entities = read_indexer_entities(entity_df, community_df, COMMUNITY_LEVEL)

# load description embeddings to an in-memory lancedb vectorstore
# to connect to a remote db, specify url and port values.
description_embedding_store = LanceDBVectorStore(
    collection_name="default-entity-description",
)
description_embedding_store.connect(db_uri=LANCEDB_URI)

full_content_embedding_store = LanceDBVectorStore(
    collection_name="default-community-full_content",
)
full_content_embedding_store.connect(db_uri=LANCEDB_URI)

print(f"Entity count: {len(entity_df)}")
entity_df.head()

relationship_df = pd.read_parquet(f"{INPUT_DIR}/{RELATIONSHIP_TABLE}.parquet")
relationships = read_indexer_relationships(relationship_df)

print(f"Relationship count: {len(relationship_df)}")
relationship_df.head()

text_unit_df = pd.read_parquet(f"{INPUT_DIR}/{TEXT_UNIT_TABLE}.parquet")
text_units = read_indexer_text_units(text_unit_df)

print(f"Text unit records: {len(text_unit_df)}")
text_unit_df.head()
# Out:
# Entity df columns: Index(['id', 'human_readable_id', 'title', 'type', 'description',
#        'text_unit_ids', 'frequency', 'degree', 'x', 'y'],
#       dtype='object')
# Entity count: 1320
# Relationship count: 2953
# Text unit records: 1430
#                                                   id  \
# 0  edc26110692c720c53dbb8cf9ccb9faa13a5a5a4bcae51...
# 1  a4a0fb6768e03c3890e9cfa1d893f93862b89429b11491...
# 2  ed5ed488725aeb71d61236bc128ac24abecacfaae95e1f...
# 3  683a17f9319ee084962a444efa461b5463b5a0c5fe2a6f...
# 4  e6175801e5fb7cfcd7dc6d9bd9ba001d403bd35bc94993...
#
#                                                 text  \
# 0  #entities_id: P453307765. #typology_id_type: 1...
# 1  #entities_id: IN0010328049. #typology_id_type:...
# 2  #entities_id: P582673405. #typology_id_type: 1...
# 3  #entities_id: FR908565575. #typology_id_type: ...
# 4  #bvd_id_number: CZ01139720. #methodology_id: 6...
#
#                                         document_ids  n_tokens
# 0  [002b0bdfbc351d5ad7eedaaf3837bbddcb653e1f4157e...        96
# 1  [003b9817b2df66da8060e809827e6b2a0e730ae94da2d...       159
# 2  [008168ec3677047bbd5305a80b7442d051781bee95d5d...        97
# 3  [009281cf16e16082d5e152adb57678dc5fac9c0041a77...       148
# 4  [00dcc74cb38c7aae10bcc8a2809d96fe41c723feb653b...       166

# %%
# api_key = os.environ["GRAPHRAG_API_KEY"]
# llm_model = os.environ["GRAPHRAG_LLM_MODEL"]
# embedding_model = os.environ["GRAPHRAG_EMBEDDING_MODEL"]

api_key = "your_api_key"
llm_model = "gpt-4o-mini"
embedding_model = "text-embedding-3-small"

chat_config = LanguageModelConfig(
    api_key=api_key,
    type=ModelType.OpenAIChat,
    model=llm_model,
    max_retries=20,
)
chat_model = ModelManager().get_or_create_chat_model(
    name="local_search",
    model_type=ModelType.OpenAIChat,
    config=chat_config,
)

token_encoder = tiktoken.encoding_for_model(llm_model)

embedding_config = LanguageModelConfig(
    api_key=api_key,
    type=ModelType.OpenAIEmbedding,
    model=embedding_model,
    max_retries=20,
)

text_embedder = ModelManager().get_or_create_embedding_model(
    name="local_search_embedding",
    model_type=ModelType.OpenAIEmbedding,
    config=embedding_config,
)

# %%
def read_community_reports(
    input_dir: str,
    community_report_table: str = COMMUNITY_REPORT_TABLE,
):
    """Embeds the full content of the community reports and saves the DataFrame with embeddings to the output path."""
    input_path = Path(input_dir) / f"{community_report_table}.parquet"
    return pd.read_parquet(input_path)


report_df = read_community_reports(INPUT_DIR)
reports = read_indexer_reports(
    report_df,
    community_df,
    COMMUNITY_LEVEL,
    content_embedding_col="full_content_embeddings",
)
read_indexer_report_embeddings(reports, full_content_embedding_store)

# %%
drift_params = DRIFTSearchConfig(
    temperature=0,
    max_tokens=12_000,
    primer_folds=1,
    drift_k_followups=3,
    n_depth=3,
    n=1,
)

context_builder = DRIFTSearchContextBuilder(
    model=chat_model,
    text_embedder=text_embedder,
    entities=entities,
    relationships=relationships,
    reports=reports,
    entity_text_embeddings=description_embedding_store,
    text_units=text_units,
    token_encoder=token_encoder,
    config=drift_params,
)

search = DRIFTSearch(
    model=chat_model, context_builder=context_builder, token_encoder=token_encoder
)

# %%
resp = await search.search("Tell me about Palladia Limited.")

# %%
resp.response
# Out:
# "## Overview of Palladia Limited\n\nPalladia Limited was a private limited company incorporated in the United Kingdom on March 17, 2005, and it was dissolved on February 1, 2011. The company had a limited governance structure, with only one current director and one previous director recorded at the time of its dissolution [Data: Sources (36, 248)].\n\n### Governance Concerns\n\nThe governance dynamics of Palladia Limited raise significant concerns, particularly regarding the nature of its directorship. The presence of only one current and one previous director suggests a lack of diversity in leadership, which can be a risk factor for governance failures. This is compounded by the atypical directorship patterns observed among its directors, where individuals hold multiple directorships across various entities, potentially leading to conflicts of interest [Data: Reports (1)].\n\n### Atypical Directorship Patterns\n\nPalladia Limited has been flagged for atypical directorship patterns, which may indicate irregularities in governance. For instance, Robert Richard William Falls has held 99 directorships, and Celementina Diaz De Macias has an extensive record of 1,073 directorships. Such high concentrations of directorships among individuals raise concerns about potential conflicts of interest and the effectiveness of oversight within the organizations they are associated with [Data: Reports (1)].\n\n### Risks and Implications\n\nThe interconnectedness of Palladia Limited's directors across various entities suggests the potential for circular ownership structures, which can obscure accountability and create governance risks. Additionally, the presence of inactive directorships among its former directors, with some holding as many as ten inactive positions, indicates a lack of engagement or oversight [Data: Reports (1)].\n\nJurisdictional risks are also a concern, as Palladia Limited operated in the UK while other entities linked to its directors are based in jurisdictions like South Africa. This disparity raises questions about regulatory compliance and the potential for exploitation of legal loopholes [Data: Reports (1)].\n\n### Conclusion\n\nIn summary, Palladia Limited's governance structure reflects broader concerns in corporate governance practices, particularly regarding transparency and the potential for conflicts of interest. The company's history of directorships and its eventual dissolution prompt inquiries into its previous activities and the reasons behind its governance failures. Understanding these factors is crucial for stakeholders assessing the legacy and potential risks associated with the company and its directors [Data: Reports (1)]."

# %%
print(resp.context_data)
# Out:
# {'Can you provide more details about the directors of Palladia Limited?': {'reports':   id                                              title  \
# 0  1  Corporate Governance Dynamics in China and the UK
#
#                                              content
# 0  # Corporate Governance Dynamics in China and t...  , 'entities': Empty DataFrame
# Columns: [in_context]
# Index: [], 'sources':       id                                               text
# 0    248  #bvd_id_number: GB05396445. #methodology_id: 1...
# 1     36  #entities_id: GB05396445. #typology_id_type: 0...
# 2    724  #bvd_id_number: GB04263411. #methodology_id: 1...
# 3    939  #entities_id: GB04263411. #typology_id_type: 0...
# 4    577  #bvd_id_number: IE449986. #methodology_id: 1 (...
# 5    728  #bvd_id_number: GB08191636. #methodology_id: 1...
# 6    932  #bvd_id_number: ZA200820210523. #methodology_i...
# 7     23  #bvd_id_number: NZ9429050646036. #methodology_...
# 8    703  #bvd_id_number: PA437068RPP. #methodology_id: ...
# 9     70  #entities_id: PA437068RPP. #typology_id_type: ...
# 10    49  #bvd_id_number: PA476579RPP. #methodology_id: ...
# 11   732  #entities_id: PA476579RPP. #typology_id_type: ...
# 12   269  #bvd_id_number: GB08721918. #methodology_id: 1...
# 13    74  #entities_id: CVA0337060. #typology_id_type: 1...
# 14   429  #entities_id: P515719391. #typology_id_type: 1...
# 15   514  #entities_id: CVA0343109. #typology_id_type: 1...
# 16   587  #entities_id: CVA0343104. #typology_id_type: 1...
# 17   597  #entities_id: PA722133RPP. #typology_id_type: ...
# 18  1070  #entities_id: P061217860. #typology_id_type: 1...
# 19  1202  #entities_id: P239514020. #typology_id_type: 1...
# 20   168  #bvd_id_number: SG202349043D. #methodology_id:...
# 21    75  #entities_id: SG202349043D. #typology_id_type:...
# 22  1290  #bvd_id_number: PA34854RPP. #methodology_id: 1...
# 23   171  #bvd_id_number: AU669464082. #methodology_id: ...
# 24   344  #bvd_id_number: AU102324569. #methodology_id: ...
# 25    58  #entities_id: AU102324569. #typology_id_type: ...
# 26   950  #bvd_id_number: GB03043883. #methodology_id: 1...
# 27   225  #entities_id: GB03043883. #typology_id_type: 0...
# 28   626  #bvd_id_number: IN0010686786. #methodology_id:...
# 29   502  #entities_id: IN0010686786. #typology_id_type:...
# 30  1365  #bvd_id_number: PA722133RPP. #methodology_id: ...}, 'What are the implications of having multiple directorships for corporate governance?': {'reports':   id                                              title  \
# 0  1  Corporate Governance Dynamics in China and the UK
#
#                                              content
# 0  # Corporate Governance Dynamics in China and t...  , 'entities': Empty DataFrame
# Columns: [in_context]
# Index: [], 'sources':       id                                               text
# 0    168  #bvd_id_number: SG202349043D. #methodology_id:...
# 1    262  #bvd_id_number: NO939525823. #methodology_id: ...
# 2    707  #bvd_id_number: SE5594517343. #methodology_id:...
# 3   1429  #bvd_id_number: FR908564727. #methodology_id: ...
# 4   1370  #bvd_id_number: GB15411596. #methodology_id: 2...
# ..   ...                                                ...
# 72   975  #bvd_id_number: NZ9429051466749. #methodology_...
# 73  1037  #bvd_id_number: TH0105565030691. #methodology_...
# 74  1093  #bvd_id_number: IT07647310585. #methodology_id...
# 75  1121  #bvd_id_number: SE5568374515. #methodology_id:...
# 76  1246  #bvd_id_number: GBSC324192. #methodology_id: 1...
#
# [77 rows x 2 columns]}, 'What are the risks associated with circular ownership structures in companies?': {'reports':   id                                              title  \
# 0  9  Circular Ownership in Indian Private Limited C...
#
#                                              content
# 0  # Circular Ownership in Indian Private Limited...  , 'entities': Empty DataFrame
# Columns: [in_context]
# Index: [], 'sources':       id                                               text
# 0    102  #bvd_id_number: IN0013788034. #methodology_id:...
# 1    291  #bvd_id_number: IN0007975685. #methodology_id:...
# 2    296  #bvd_id_number: JP2010001139173. #methodology_...
# 3    336  #bvd_id_number: IN0013749408. #methodology_id:...
# 4    509  #bvd_id_number: IN0001585016. #methodology_id:...
# 5    523  #bvd_id_number: IN0008200151. #methodology_id:...
# 6    619  #bvd_id_number: CN9360502505. #methodology_id:...
# 7    626  #bvd_id_number: IN0010686786. #methodology_id:...
# 8    674  #bvd_id_number: SG193100023M. #methodology_id:...
# 9    717  #bvd_id_number: JP4250001006505. #methodology_...
# 10   791  #bvd_id_number: FR811280718. #methodology_id: ...
# 11   792  #bvd_id_number: IN0008734857. #methodology_id:...
# 12   820  #bvd_id_number: IN0002996418. #methodology_id:...
# 13   962  #bvd_id_number: LULB122811. #methodology_id: 3...
# 14  1040  #bvd_id_number: JP6180001007509. #methodology_...
# 15  1068  #bvd_id_number: IN0010338586. #methodology_id:...}, 'How do different jurisdictions regulate circular ownership structures?': {'reports':   id                                              title  \
# 0  9  Circular Ownership in Indian Private Limited C...
#
#                                              content
# 0  # Circular Ownership in Indian Private Limited...  , 'entities': Empty DataFrame
# Columns: [in_context]
# Index: [], 'sources':       id                                               text
# 0    102  #bvd_id_number: IN0013788034. #methodology_id:...
# 1    291  #bvd_id_number: IN0007975685. #methodology_id:...
# 2    296  #bvd_id_number: JP2010001139173. #methodology_...
# 3    336  #bvd_id_number: IN0013749408. #methodology_id:...
# 4    509  #bvd_id_number: IN0001585016. #methodology_id:...
# 5    523  #bvd_id_number: IN0008200151. #methodology_id:...
# 6    619  #bvd_id_number: CN9360502505. #methodology_id:...
# 7    626  #bvd_id_number: IN0010686786. #methodology_id:...
# 8    674  #bvd_id_number: SG193100023M. #methodology_id:...
# 9    717  #bvd_id_number: JP4250001006505. #methodology_...
# 10   791  #bvd_id_number: FR811280718. #methodology_id: ...
# 11   792  #bvd_id_number: IN0008734857. #methodology_id:...
# 12   820  #bvd_id_number: IN0002996418. #methodology_id:...
# 13   962  #bvd_id_number: LULB122811. #methodology_id: 3...
# 14  1040  #bvd_id_number: JP6180001007509. #methodology_...
# 15  1068  #bvd_id_number: IN0010338586. #methodology_id:...}, 'What role do shareholders play in overseeing directors with multiple directorships?': {'reports':   id                                              title  \
# 0  1  Corporate Governance Dynamics in China and the UK
#
#                                              content
# 0  # Corporate Governance Dynamics in China and t...  , 'entities': Empty DataFrame
# Columns: [in_context]
# Index: [], 'sources':       id                                               text
# 0    168  #bvd_id_number: SG202349043D. #methodology_id:...
# 1    262  #bvd_id_number: NO939525823. #methodology_id: ...
# 2    707  #bvd_id_number: SE5594517343. #methodology_id:...
# 3   1429  #bvd_id_number: FR908564727. #methodology_id: ...
# 4   1370  #bvd_id_number: GB15411596. #methodology_id: 2...
# ..   ...                                                ...
# 72  1135  #bvd_id_number: ESV79983151. #methodology_id: ...
# 73  1246  #bvd_id_number: GBSC324192. #methodology_id: 1...
# 74  1290  #bvd_id_number: PA34854RPP. #methodology_id: 1...
# 75  1304  #bvd_id_number: CN9453891276. #methodology_id:...
# 76  1306  #bvd_id_number: CN9390945105. #methodology_id:...
#
# [77 rows x 2 columns]}, 'Can you provide information on the previous director of Palladia Limited?': {'reports':   id                                              title  \
# 0  1  Corporate Governance Dynamics in China and the UK
#
#                                              content
# 0  # Corporate Governance Dynamics in China and t...  , 'entities': Empty DataFrame
# Columns: [in_context]
# Index: [], 'sources':      id                                               text
# 0   248  #bvd_id_number: GB05396445. #methodology_id: 1...
# 1    36  #entities_id: GB05396445. #typology_id_type: 0...
# 2   577  #bvd_id_number: IE449986. #methodology_id: 1 (...
# 3   724  #bvd_id_number: GB04263411. #methodology_id: 1...
# 4   939  #entities_id: GB04263411. #typology_id_type: 0...
# 5   932  #bvd_id_number: ZA200820210523. #methodology_i...
# 6   728  #bvd_id_number: GB08191636. #methodology_id: 1...
# 7   171  #bvd_id_number: AU669464082. #methodology_id: ...
# 8   970  #bvd_id_number: GBFC022923. #methodology_id: 1...
# 9   189  #entities_id: P003392313. #typology_id_type: 1...
# 10   23  #bvd_id_number: NZ9429050646036. #methodology_...
# 11  184  #bvd_id_number: GBOC397263. #methodology_id: 4...
# 12  507  #bvd_id_number: MM000093291MMR. #methodology_i...
# 13  950  #bvd_id_number: GB03043883. #methodology_id: 1...
# 14  225  #entities_id: GB03043883. #typology_id_type: 0...
# 15  344  #bvd_id_number: AU102324569. #methodology_id: ...
# 16   58  #entities_id: AU102324569. #typology_id_type: ...
# 17  269  #bvd_id_number: GB08721918. #methodology_id: 1...
# 18   63  #bvd_id_number: FR438473795. #methodology_id: ...
# 19  812  #bvd_id_number: IE519471. #methodology_id: 1 (...
# 20  113  #entities_id: P041929636. #typology_id_type: 1...
# 21   49  #bvd_id_number: PA476579RPP. #methodology_id: ...
# 22  732  #entities_id: PA476579RPP. #typology_id_type: ...
# 23  126  #bvd_id_number: GB07030259. #methodology_id: 1...
# 24  198  #entities_id: GB07030259. #typology_id_type: 0...
# 25  678  #bvd_id_number: YY*110140133778. #methodology_...}, 'What are the implications of atypical directorship patterns in corporate governance?': {'reports':   id                                              title  \
# 0  1  Corporate Governance Dynamics in China and the UK
#
#                                              content
# 0  # Corporate Governance Dynamics in China and t...  , 'entities': Empty DataFrame
# Columns: [in_context]
# Index: [], 'sources':       id                                               text
# 0     23  #bvd_id_number: NZ9429050646036. #methodology_...
# 1     25  #bvd_id_number: CN9366707082. #methodology_id:...
# 2     49  #bvd_id_number: PA476579RPP. #methodology_id: ...
# 3     63  #bvd_id_number: FR438473795. #methodology_id: ...
# 4     86  #bvd_id_number: IN0001778368. #methodology_id:...
# ..   ...                                                ...
# 73   678  #bvd_id_number: YY*110140133778. #methodology_...
# 74   741  #bvd_id_number: YY*918692791. #methodology_id:...
# 75   920  #bvd_id_number: JP3180001022262. #methodology_...
# 76  1084  #bvd_id_number: PK*110190952705. #methodology_...
# 77  1165  #bvd_id_number: ZA2-21069. #methodology_id: 4 ...
#
# [78 rows x 2 columns]}, 'How does Palladia Limited compare to other companies with similar governance structures?': {'reports':   id                                              title  \
# 0  1  Corporate Governance Dynamics in China and the UK
#
#                                              content
# 0  # Corporate Governance Dynamics in China and t...  , 'entities': Empty DataFrame
# Columns: [in_context]
# Index: [], 'sources':       id                                               text
# 0    248  #bvd_id_number: GB05396445. #methodology_id: 1...
# 1     36  #entities_id: GB05396445. #typology_id_type: 0...
# 2     49  #bvd_id_number: PA476579RPP. #methodology_id: ...
# 3    732  #entities_id: PA476579RPP. #typology_id_type: ...
# 4   1365  #bvd_id_number: PA722133RPP. #methodology_id: ...
# 5    597  #entities_id: PA722133RPP. #typology_id_type: ...
# 6     70  #entities_id: PA437068RPP. #typology_id_type: ...
# 7     74  #entities_id: CVA0337060. #typology_id_type: 1...
# 8    429  #entities_id: P515719391. #typology_id_type: 1...
# 9    514  #entities_id: CVA0343109. #typology_id_type: 1...
# 10   587  #entities_id: CVA0343104. #typology_id_type: 1...
# 11  1070  #entities_id: P061217860. #typology_id_type: 1...
# 12  1202  #entities_id: P239514020. #typology_id_type: 1...
# 13   724  #bvd_id_number: GB04263411. #methodology_id: 1...
# 14   939  #entities_id: GB04263411. #typology_id_type: 0...
# 15  1068  #bvd_id_number: IN0010338586. #methodology_id:...
# 16   260  #entities_id: IN0000679963. #typology_id_type:...
# 17  1290  #bvd_id_number: PA34854RPP. #methodology_id: 1...
# 18   168  #bvd_id_number: SG202349043D. #methodology_id:...
# 19   262  #bvd_id_number: NO939525823. #methodology_id: ...
# 20   707  #bvd_id_number: SE5594517343. #methodology_id:...
# 21  1429  #bvd_id_number: FR908564727. #methodology_id: ...
# 22  1370  #bvd_id_number: GB15411596. #methodology_id: 2...
# 23    45  #bvd_id_number: NZ9429052512704. #methodology_...
# 24   174  #bvd_id_number: GR006109601000. #methodology_i...
# 25   655  #bvd_id_number: NL09208709. #methodology_id: 2...
# 26   337  #bvd_id_number: CN9376610728. #methodology_id:...
# 27   852  #bvd_id_number: CN9450167887. #methodology_id:...
# 28   427  #bvd_id_number: VG*L000000336564. #methodology...
# 29   703  #bvd_id_number: PA437068RPP. #methodology_id: ...
# 30   950  #bvd_id_number: GB03043883. #methodology_id: 1...
# 31   225  #entities_id: GB03043883. #typology_id_type: 0...
# 32   321  #entities_id: IN0003044451. #typology_id_type:...
# 33  1138  #bvd_id_number: IN0010034891. #methodology_id:...
# 34   728  #bvd_id_number: GB08191636. #methodology_id: 1...
# 35   523  #bvd_id_number: IN0008200151. #methodology_id:...
# 36   914  #entities_id: IN0006894969. #typology_id_type:...
# 37    23  #bvd_id_number: NZ9429050646036. #methodology_...
# 38  1226  #entities_id: NZ9429050646036. #typology_id_ty...
# 39   820  #bvd_id_number: IN0002996418. #methodology_id:...
# 40   821   'IN0002996418'], dtype=object),\n        arra...
# 41   376  #entities_id: IN0002996418. #typology_id_type:...
# 42   344  #bvd_id_number: AU102324569. #methodology_id: ...
# 43    58  #entities_id: AU102324569. #typology_id_type: ...
# 44  1139  0.25', '1.30', '2.35', '2.73'], dtype=object)]...}, 'How do different jurisdictions regulate directorship disclosures?': {'reports':   id                                              title  \
# 0  1  Corporate Governance Dynamics in China and the UK
# 1  8  Jurisdictional Risk Disparity in Corporate Gov...
#
#                                              content
# 0  # Corporate Governance Dynamics in China and t...
# 1  # Jurisdictional Risk Disparity in Corporate G...  , 'entities': Empty DataFrame
# Columns: [in_context]
# Index: [], 'sources':       id                                               text
# 0    168  #bvd_id_number: SG202349043D. #methodology_id:...
# 1    262  #bvd_id_number: NO939525823. #methodology_id: ...
# 2    707  #bvd_id_number: SE5594517343. #methodology_id:...
# 3   1429  #bvd_id_number: FR908564727. #methodology_id: ...
# 4   1370  #bvd_id_number: GB15411596. #methodology_id: 2...
# 5     45  #bvd_id_number: NZ9429052512704. #methodology_...
# 6    174  #bvd_id_number: GR006109601000. #methodology_i...
# 7    655  #bvd_id_number: NL09208709. #methodology_id: 2...
# 8    337  #bvd_id_number: CN9376610728. #methodology_id:...
# 9    852  #bvd_id_number: CN9450167887. #methodology_id:...
# 10   171  #bvd_id_number: AU669464082. #methodology_id: ...
# 11   427  #bvd_id_number: VG*L000000336564. #methodology...
# 12   482  #bvd_id_number: AU609165728. #methodology_id: ...
# 13   678  #bvd_id_number: YY*110140133778. #methodology_...
# 14   741  #bvd_id_number: YY*918692791. #methodology_id:...
# 15   920  #bvd_id_number: JP3180001022262. #methodology_...
# 16  1084  #bvd_id_number: PK*110190952705. #methodology_...
# 17  1165  #bvd_id_number: ZA2-21069. #methodology_id: 4 ...
# 18   184  #bvd_id_number: GBOC397263. #methodology_id: 4...
# 19  1220  #bvd_id_number: GB11933878. #methodology_id: 4...
# 20  1242  #bvd_id_number: ZA202453545907. #methodology_i...
# 21    39  #bvd_id_number: MA238255-81. #methodology_id: ...
# 22    82  #bvd_id_number: ZA202467761107. #methodology_i...
# 23   101  #bvd_id_number: GB04638743. #methodology_id: 4...
# 24   155  #bvd_id_number: MM000177307MMR. #methodology_i...
# 25   191  #bvd_id_number: KECPR2016-014265. #methodology...
# 26   207  #bvd_id_number: GB07211283. #methodology_id: 4...
# 27   214  #bvd_id_number: GB15392898. #methodology_id: 4...
# 28   229  #bvd_id_number: TW03004509. #methodology_id: 4...
# 29   245  #bvd_id_number: ZA202318183807. #methodology_i...
# 30   477  #bvd_id_number: ZA202230764407. #methodology_i...
# 31   507  #bvd_id_number: MM000093291MMR. #methodology_i...
# 32   550  #bvd_id_number: ZA202447085407. #methodology_i...
# 33   622  #bvd_id_number: GB08169634. #methodology_id: 4...
# 34   759  #bvd_id_number: GB14718969. #methodology_id: 4...
# 35   839  #bvd_id_number: KEC16245. #methodology_id: 4 (...
# 36   923  #bvd_id_number: NO929382390. #methodology_id: ...
# 37   935  #bvd_id_number: NL41166415. #methodology_id: 4...
# 38  1005  #bvd_id_number: GB15255459. #methodology_id: 4...
# 39  1045  #bvd_id_number: EE14848691. #methodology_id: 4...
# 40  1136  #bvd_id_number: BG203148821. #methodology_id: ...
# 41  1149  #bvd_id_number: ZA202456145307. #methodology_i...
# 42  1167  #bvd_id_number: ZA202412595907. #methodology_i...
# 43  1195  #bvd_id_number: ZA201643688807. #methodology_i...
# 44  1257  #bvd_id_number: ZA202411484207. #methodology_i...
# 45  1311  #bvd_id_number: ZA202358423607. #methodology_i...
# 46    57  #bvd_id_number: GB12336324. #methodology_id: 4...
# 47   246  #bvd_id_number: RU55983490. #methodology_id: 4...
# 48   307  #bvd_id_number: ITSMNNTM83A53Z129K. #methodolo...
# 49   361  #bvd_id_number: RU71326343. #methodology_id: 4...
# 50   398  #bvd_id_number: RU0196242248. #methodology_id:...
# 51   406  #bvd_id_number: CHCHE420337663. #methodology_i...
# 52   453  #bvd_id_number: HR72424949528. #methodology_id...
# 53   485  #bvd_id_number: RU0197578314. #methodology_id:...
# 54   515  #bvd_id_number: GB11225418. #methodology_id: 4...
# 55   567  #bvd_id_number: RU0112298397. #methodology_id:...
# 56   568  #bvd_id_number: GB13937528. #methodology_id: 4...
# 57   630  #bvd_id_number: BG201609262. #methodology_id: ...}}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
